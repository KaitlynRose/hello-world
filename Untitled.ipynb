# %%
import random

def payoff(row,column):
    if (row+column)%2 == 0:
        pay = row + column
    else:
        pay = -(row + column)
    return pay

def getrowfinger():
    goodentry = False
    while not goodentry:
        rowfinger = int(input("Enter 1 or 2: "))
        if rowfinger == 1 or rowfinger == 2:
            goodentry = True
        else:
            print("Invalid entry. Try again")
        return rowfinger

def getcolfinger(now):
    rnd = random.randint(1,100)
    if rnd <= now:
        colmfinger = 1
    else:
        colmfinger = 2
    return colmfinger


#main
rdscore = 0
totalscore = 0
onesforrow = 0

numrounds = int(input("how many times do you want to play"))
colm_percent_q = int(input("Enter the percent  of 1's played by column: "))
print("Ok, now we'll play!")
for r in range (numrounds):
    row = getrowfinger()
    colm = getcolfinger(colm_percent_q)
    if row == 1:
        onesforrow += 1
    rdscore = payoff (row,colm)
    totalscore = totalscore + rdscore
    print("You played ", row, "computer played ", colm,"Score = ", rdscore)
    print("row percent ones = ", onesforrow/(r+1))
    

percentuno = onesforrow/numrounds
if totalscore > 0:
    print ("You Won!!!")
elif totalscore== 0:
    print("We Tied")
else:
    print("You Lose")

print("Final Score =",totalscore)
print("Percent of 1's played by Row =", percentuno)
print("plays", numrounds)
print("Average points per play: ", totalscore/numrounds)
# Out:
# how many times do you want to play10
# Enter the percent  of 1's played by column: 25
# Ok, now we'll play!
# Enter 1 or 2: 1
# You played  1 computer played  2 Score =  -3
# row percent ones =  1.0
# Enter 1 or 2: 1
# You played  1 computer played  2 Score =  -3
# row percent ones =  1.0
# Enter 1 or 2: 2
# You played  2 computer played  2 Score =  4
# row percent ones =  0.6666666666666666
# Enter 1 or 2: 2
# You played  2 computer played  2 Score =  4
# row percent ones =  0.5
# Enter 1 or 2: 2
# You played  2 computer played  1 Score =  -3
# row percent ones =  0.4
# Enter 1 or 2: 2
# You played  2 computer played  2 Score =  4
# row percent ones =  0.3333333333333333
# Enter 1 or 2: 2
# You played  2 computer played  1 Score =  -3
# row percent ones =  0.2857142857142857
# Enter 1 or 2: 2
# You played  2 computer played  2 Score =  4
# row percent ones =  0.25
# Enter 1 or 2: 2
# You played  2 computer played  2 Score =  4
# row percent ones =  0.2222222222222222
# ...

# %%
import random

def payoff(row,column):
    if (row+column)%2 == 0:
        pay = row + column
    else:
        pay = -(row + column)
    return pay

def getrowmove():
    goodentry = False
    while not goodentry:
        rowfinger =input("Enter 1 or 2: ")
        if rowmove == "Rock" or rowmove == "Paper" or rowmove == "Scissors":
            goodentry = True
        else:
            print("Invalid entry. Try again")
        return rowmove

def getcolmove(now):
    rnd = random.randint(1,100)
    if rnd <= now:
        colmove = "Rock"
    elif rnd == now:
        colmove = "Scissors"
    else:
        colmove = "Paper"
    return colmfinger


#main
rdscore = 0
totalscore = 0
onesforrow = 0

numrounds = int(input("how many times do you want to play"))
colm_percent_q = int(input("Enter the percent  of 1's played by column: "))
print("Ok, now we'll play!")
for r in range (numrounds):
    row = getrowmove()
    colm = getcolmove(colm_percent_q)
    if row == 1:
        onesforrow += 1
    rdscore = payoff (row,colm)
    totalscore = totalscore + rdscore
    print("You played ", row, "computer played ", colm,"Score = ", rdscore)
    print("row percent ones = ", onesforrow/(r+1))
    

percentuno = onesforrow/numrounds
if totalscore > 0:
    print ("You Won!!!")
elif totalscore== 0:
    print("We Tied")
else:
    print("You Lose")

print("Final Score =",totalscore)
print("Percent of 1's played by Row =", percentuno)
print("plays", numrounds)
print("Average points per play: ", totalscore/numrounds)
